# %% [markdown]
# ## Baccalauréat
#
# __Objectif__
#
# traiter les données dans le fichier

# %%
import csv

# %%
import csv
fichier=open("fr-en-baccalaureat-par-academie.csv")
table=list(csv.DictReader(fichier,delimiter=";"))
table=[dict(i) for i in table]
table
# Out:
# [{'\ufeffnum_ligne': '43.0',
#   'Session': '2021',
#   'Code académie': '02',
#   'Académie': 'AIX-MARSEILLE',
#   'Sexe': 'FEMININ',
#   'Statut du candidat': 'FORMATION CONTINUE',
#   'Voie': 'BAC PROFESSIONNEL',
#   'Série': 'BAC PRO SERV',
#   'Diplôme spécialité': 'BAC PRO 32304 PHOTOGRAPHIE',
#   "Nombre d'inscrits": '5',
#   'Nombre de présents': '4',
#   "Nombre d'admis au 1er groupe": '2',
#   'Nombre de refusés au 1er groupe': '2',
#   "Nombre d'ajournés, passant les épreuves du 2nd groupe": '0',
#   "Nombre d'admis à l'issue du 2nd groupe": '0',
#   "Nombre de refusés à l'issue du 2nd groupe": '0',
#   "Nombre d'admis totaux": '2',
#   "Nombre d'admis avec mention TB avec les félicitations du jury": '0',
#   "Nombre d'admis avec mention TB sans les félicitations du jury": '1',
#   "Nombre d'admis avec mention B": '0',
#   "Nombre d'admis avec mention AB": '0',
#   "Nombre d'admis sans mention": '1',
#   'Nombre de refusés totaux': '2'},
#  {'\ufeffnum_ligne': '52.0',
# ...
